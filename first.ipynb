# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("placement.csv")

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X=df.iloc[:,0:2]

# %%
Y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.1,
    random_state=42
    
)

# %%
X_test
# Out:
#     cgpa     iq
# 83   7.5  130.0
# 53   8.3  168.0
# 70   6.3  127.0
# 45   6.0   66.0
# 44   7.5   61.0
# 39   4.6  146.0
# 22   4.9  120.0
# 80   4.9  196.0
# 10   6.0   45.0
# 0    6.8  123.0

# %%
X_train
# Out:
#     cgpa     iq
# 18   4.0  100.0
# 30   7.6  128.0
# 73   4.9   61.0
# 33   6.0  149.0
# 90   7.3   86.0
# ..   ...    ...
# 60   6.9  139.0
# 71   6.1  132.0
# 14   6.1  103.0
# 92   5.2  110.0
# 51   4.8  141.0
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.73718527, -0.62029848],
#        [ 1.45537303,  0.09806189],
#        [-0.9390457 , -1.62087186],
#        [ 0.03645823,  0.63683217],
#        [ 1.1893265 , -0.97947867],
#        [-0.14090612,  0.45724208],
#        [-0.9390457 ,  0.79076654],
#        [ 1.1893265 , -1.90308486],
#        [-0.49563482,  0.3802749 ],
#        [-1.82586745, -0.38939693],
#        [ 1.63273738, -0.26111829],
#        [-1.38245657,  0.63683217],
#        [ 0.92327998,  1.91961855],
#        [ 1.45537303, -0.90251149],
#        [ 2.2535126 , -0.10718393],
#        [-0.76168135,  1.32953682],
#        [-0.9390457 ,  0.25199626],
#        [-1.38245657, -2.10833068],
#        [-0.76168135, -1.49259322],
#        [ 1.1893265 , -0.20980684],
#        [ 0.8345978 ,  0.35461917],
#        [-0.67299917,  0.9447009 ],
#        [-0.14090612,  1.07297954],
#        [-0.67299917, -0.87685576],
#        [ 0.74591563, -0.31242975],
#        [ 1.01196215, -1.95439632],
#        [ 0.8345978 , -0.72292139],
#        [ 1.8987839 ,  1.07297954],
#        [ 0.74591563, -0.87685576],
#        [-0.67299917,  2.56101175],
#        [-0.49563482,  0.27765199],
#        [-1.02772787,  0.99601236],
#        [-0.85036352, -1.5695604 ],
#        [-1.47113875,  1.94527428],
#        [ 0.03645823, -0.00456102],
#        [-0.67299917,  0.2006848 ],
#        [-0.49563482, -0.44070839],
#        [-0.85036352, -0.85120003],
#        [ 0.03645823, -0.56898703],
#        [ 0.39118693, -0.20980684],
#        [-1.11641005, -0.0815282 ],
#        [ 1.27800868,  0.2006848 ],
#        [-2.3579605 ,  1.50912691],
#        [ 0.4798691 ,  0.91904518],
#        [ 0.1251404 ,  0.81642227],
#        [ 0.1251404 , -1.10775731],
#        [-0.2295883 ,  0.48289781],
#        [ 0.92327998, -1.54390468],
#        [-0.2295883 ,  0.40593062],
#        [-0.9390457 ,  0.68814363],
#        [ 0.1251404 , -1.51824895],
#        [ 0.21382258, -0.28677402],
#        [ 0.39118693,  0.43158635],
#        [ 0.74591563,  0.43158635],
#        [-2.18059615,  2.79191329],
#        [-0.85036352, -0.15849538],
#        [-0.584317  , -0.26111829],
#        [-1.73718527, -1.26169167],
#        [ 1.1893265 ,  0.32896344],
#        [ 0.65723345,  1.48347118],
#        [ 0.4798691 , -0.87685576],
#        [-0.49563482, -0.26111829],
#        [ 1.81010173, -1.15906876],
#        [ 0.56855128,  0.35461917],
#        [ 0.30250475, -0.5433313 ],
#        [ 0.4798691 ,  0.14937335],
#        [-1.02772787,  1.14994673],
#        [ 0.92327998,  0.3802749 ],
#        [-1.11641005, -1.85177341],
#        [-1.02772787, -0.31242975],
#        [ 0.30250475,  0.09806189],
#        [-0.2295883 ,  1.14994673],
#        [ 1.8987839 ,  0.63683217],
#        [ 0.92327998, -0.31242975],
#        [-0.05222395, -0.46636412],
#        [ 0.92327998,  1.30388109],
#        [ 1.01196215,  0.68814363],
#        [-0.584317  , -0.0815282 ],
#        [-1.11641005, -0.95382294],
#        [-0.2295883 ,  0.2006848 ],
#        [ 1.36669085,  0.86773372],
#        [ 0.65723345,  0.76511081],
#        [-0.76168135,  0.09806189],
#        [ 0.4798691 , -2.23660932],
#        [ 0.56855128, -0.10718393],
#        [ 0.8345978 ,  0.3802749 ],
#        [ 0.1251404 ,  0.2006848 ],
#        [ 0.1251404 , -0.5433313 ],
#        [-0.67299917, -0.36374121],
#        [-1.02772787,  0.43158635]])

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.36669085,  0.14937335],
#        [ 2.07614825,  1.124291  ],
#        [ 0.30250475,  0.07240616],
#        [ 0.03645823, -1.49259322],
#        [ 1.36669085, -1.62087186],
#        [-1.20509222,  0.55986499],
#        [-0.9390457 , -0.10718393],
#        [-0.9390457 ,  1.84265137],
#        [ 0.03645823, -2.0313635 ],
#        [ 0.74591563, -0.03021675]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_predict=clf.predict(X_test)
y_predict
# Out:
# array([1, 1, 1, 0, 1, 0, 0, 0, 0, 1])

# %%
Y_test
# Out:
# 83    1
# 53    1
# 70    1
# 45    1
# 44    1
# 39    0
# 22    0
# 80    0
# 10    1
# 0     1
# Name: placement, dtype: int64

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\user\desktop\mlpractical\venv\lib\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from mlxtend) (2.4.3)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from mlxtend) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\user\desktop\mlpractical\venv\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,y_predict)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions
     

plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

pickle.dump(clf, open("model.pkl", "wb"))
pickle.dump(scaler, open("scaler.pkl", "wb"))

# %%
import pickle
import numpy as np

model = pickle.load(open("model.pkl", "rb"))

tests = [
    [5.0, 90],
    [5.0, 140],
    [6.0, 120],
    [8.0, 80]
]

for t in tests:
    print(t, "->", model.predict(np.array([t])))
# Out:
# [5.0, 90] -> [1]
# [5.0, 140] -> [1]
# [6.0, 120] -> [1]
# [8.0, 80] -> [1]
